# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('../DataSets/Fleet Data.csv')

# %%
df
# Out:
#        Parent Airline          Airline                     Aircraft Type  \
# 0     Aegean Airlines  Aegean Airlines                       Airbus A319
# 1     Aegean Airlines      Olympic Air                       Airbus A319
# 2     Aegean Airlines  Aegean Airlines                       Airbus A320
# 3     Aegean Airlines      Olympic Air                       Airbus A320
# 4     Aegean Airlines  Aegean Airlines                       Airbus A321
# ...               ...              ...                               ...
# 1578          WestJet          WestJet                        Boeing 757
# 1579          WestJet          WestJet                        Boeing 767
# 1580          WestJet   WestJet Encore  De Havilland Canada DHC-8 Dash 8
# 1581         Wizz Air         Wizz Air                       Airbus A320
# 1582         Wizz Air         Wizz Air                       Airbus A321
#
#       Current  Future  Historic  Total  Orders Unit Cost Total Cost (Current)  \
# ...

# %%
df.dtypes
# Out:
# Parent Airline           object
# Airline                  object
# Aircraft Type            object
# Current                 float64
# Future                  float64
# Historic                float64
# Total                   float64
# Orders                  float64
# Unit Cost                object
# Total Cost (Current)     object
# Average Age             float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Parent Airline             0
# Airline                    0
# Aircraft Type              0
# Current                  724
# Future                  1395
# Historic                 470
# Total                     99
# Orders                  1235
# Unit Cost                 35
# Total Cost (Current)      27
# Average Age              763
# dtype: int64

# %%
df.columns
# Out:
# Index(['Parent Airline', 'Airline', 'Aircraft Type', 'Current', 'Future',
#        'Historic', 'Total', 'Orders', 'Unit Cost', 'Total Cost (Current)',
#        'Average Age'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace(" ","")
df
# Out:
#         ParentAirline          Airline                      AircraftType  \
# 0     Aegean Airlines  Aegean Airlines                       Airbus A319
# 1     Aegean Airlines      Olympic Air                       Airbus A319
# 2     Aegean Airlines  Aegean Airlines                       Airbus A320
# 3     Aegean Airlines      Olympic Air                       Airbus A320
# 4     Aegean Airlines  Aegean Airlines                       Airbus A321
# ...               ...              ...                               ...
# 1578          WestJet          WestJet                        Boeing 757
# 1579          WestJet          WestJet                        Boeing 767
# 1580          WestJet   WestJet Encore  De Havilland Canada DHC-8 Dash 8
# 1581         Wizz Air         Wizz Air                       Airbus A320
# 1582         Wizz Air         Wizz Air                       Airbus A321
#
#       Current  Future  Historic  Total  Orders UnitCost TotalCost(Current)  \
# ...

# %%
df = df.rename(columns={'TotalCost(Current)': 'Totalcost'})
df
# Out:
#         ParentAirline          Airline                      AircraftType  \
# 0     Aegean Airlines  Aegean Airlines                       Airbus A319
# 1     Aegean Airlines      Olympic Air                       Airbus A319
# 2     Aegean Airlines  Aegean Airlines                       Airbus A320
# 3     Aegean Airlines      Olympic Air                       Airbus A320
# 4     Aegean Airlines  Aegean Airlines                       Airbus A321
# ...               ...              ...                               ...
# 1578          WestJet          WestJet                        Boeing 757
# 1579          WestJet          WestJet                        Boeing 767
# 1580          WestJet   WestJet Encore  De Havilland Canada DHC-8 Dash 8
# 1581         Wizz Air         Wizz Air                       Airbus A320
# 1582         Wizz Air         Wizz Air                       Airbus A321
#
#       Current  Future  Historic  Total  Orders UnitCost Totalcost  AverageAge
# ...

# %%
df.UnitCost=df.UnitCost.replace('[$]','',regex=True)
df
# Out:
#         ParentAirline          Airline                      AircraftType  \
# 0     Aegean Airlines  Aegean Airlines                       Airbus A319
# 1     Aegean Airlines      Olympic Air                       Airbus A319
# 2     Aegean Airlines  Aegean Airlines                       Airbus A320
# 3     Aegean Airlines      Olympic Air                       Airbus A320
# 4     Aegean Airlines  Aegean Airlines                       Airbus A321
# ...               ...              ...                               ...
# 1578          WestJet          WestJet                        Boeing 757
# 1579          WestJet          WestJet                        Boeing 767
# 1580          WestJet   WestJet Encore  De Havilland Canada DHC-8 Dash 8
# 1581         Wizz Air         Wizz Air                       Airbus A320
# 1582         Wizz Air         Wizz Air                       Airbus A321
#
#       Current  Future  Historic  Total  Orders UnitCost Totalcost  AverageAge
# ...

# %%
df.Totalcost=df.Totalcost.replace('[$,]','',regex=True)
df
# Out:
#         ParentAirline          Airline                      AircraftType  \
# 0     Aegean Airlines  Aegean Airlines                       Airbus A319
# 1     Aegean Airlines      Olympic Air                       Airbus A319
# 2     Aegean Airlines  Aegean Airlines                       Airbus A320
# 3     Aegean Airlines      Olympic Air                       Airbus A320
# 4     Aegean Airlines  Aegean Airlines                       Airbus A321
# ...               ...              ...                               ...
# 1578          WestJet          WestJet                        Boeing 757
# 1579          WestJet          WestJet                        Boeing 767
# 1580          WestJet   WestJet Encore  De Havilland Canada DHC-8 Dash 8
# 1581         Wizz Air         Wizz Air                       Airbus A320
# 1582         Wizz Air         Wizz Air                       Airbus A321
#
#       Current  Future  Historic  Total  Orders UnitCost Totalcost  AverageAge
# ...

# %%
df.Current=df.Current.fillna(0)
df.Future=df.Future.fillna(0)
df.Historic=df.Historic.fillna(0)
df.UnitCost=df.UnitCost.fillna(0)
df.Totalcost=df.Totalcost.fillna(0)
df.Orders=df.Orders.fillna(0)

# %%
df[df.AircraftType=='Airbus A319']
# Out:
#          ParentAirline           Airline AircraftType  Current  Future  \
# 0      Aegean Airlines   Aegean Airlines  Airbus A319      1.0     0.0
# 1      Aegean Airlines       Olympic Air  Airbus A319      0.0     0.0
# 11            Aeroflot  Rossiya Airlines  Airbus A319     26.0     0.0
# 12            Aeroflot          Aeroflot  Airbus A319      0.0     0.0
# 13            Aeroflot   Aurora Airlines  Airbus A319     10.0     0.0
# ...                ...               ...          ...      ...     ...
# 1470          Tunisair          Tunisair  Airbus A319      4.0     0.0
# 1483  Turkish Airlines  Turkish Airlines  Airbus A319     14.0     0.0
# 1499   United Airlines   United Airlines  Airbus A319     59.0    20.0
# 1551    Virgin America    Virgin America  Airbus A319     10.0     0.0
# 1574           Volaris           Volaris  Airbus A319     15.0     0.0
#
#       Historic  Total  Orders UnitCost Totalcost  AverageAge
# ...

# %%
df['Total']=df['Total'].fillna(df[['Current','Future','Historic']].sum(axis=1))
df
# Out:
#         ParentAirline          Airline                      AircraftType  \
# 0     Aegean Airlines  Aegean Airlines                       Airbus A319
# 1     Aegean Airlines      Olympic Air                       Airbus A319
# 2     Aegean Airlines  Aegean Airlines                       Airbus A320
# 3     Aegean Airlines      Olympic Air                       Airbus A320
# 4     Aegean Airlines  Aegean Airlines                       Airbus A321
# ...               ...              ...                               ...
# 1578          WestJet          WestJet                        Boeing 757
# 1579          WestJet          WestJet                        Boeing 767
# 1580          WestJet   WestJet Encore  De Havilland Canada DHC-8 Dash 8
# 1581         Wizz Air         Wizz Air                       Airbus A320
# 1582         Wizz Air         Wizz Air                       Airbus A321
#
#       Current  Future  Historic  Total  Orders UnitCost Totalcost  AverageAge
# ...

# %%
df['AverageAge'] = df['AverageAge'].fillna(df['AverageAge'].mean())
df
# Out:
#         ParentAirline          Airline                      AircraftType  \
# 0     Aegean Airlines  Aegean Airlines                       Airbus A319
# 1     Aegean Airlines      Olympic Air                       Airbus A319
# 2     Aegean Airlines  Aegean Airlines                       Airbus A320
# 3     Aegean Airlines      Olympic Air                       Airbus A320
# 4     Aegean Airlines  Aegean Airlines                       Airbus A321
# ...               ...              ...                               ...
# 1578          WestJet          WestJet                        Boeing 757
# 1579          WestJet          WestJet                        Boeing 767
# 1580          WestJet   WestJet Encore  De Havilland Canada DHC-8 Dash 8
# 1581         Wizz Air         Wizz Air                       Airbus A320
# 1582         Wizz Air         Wizz Air                       Airbus A321
#
#       Current  Future  Historic  Total  Orders UnitCost Totalcost  AverageAge
# ...

# %%
df.groupby('ParentAirline')['Current'].sum()
# Out:
# ParentAirline
# Aegean Airlines           61.0
# Aeroflot                 282.0
# Aerolineas Argentinas     80.0
# Air Algerie               56.0
# Air Arabia                46.0
#                          ...
# Virgin Australia         147.0
# Volaris                   68.0
# WestJet                  151.0
# Wizz Air                  74.0
# easyJet                  260.0
# Name: Current, Length: 117, dtype: float64

# %%
df.groupby('ParentAirline')['Future'].sum()
# Out:
# ParentAirline
# Aegean Airlines           0.0
# Aeroflot                 12.0
# Aerolineas Argentinas     3.0
# Air Algerie               1.0
# Air Arabia                0.0
#                          ...
# Virgin Australia          1.0
# Volaris                   4.0
# WestJet                   1.0
# Wizz Air                  4.0
# easyJet                   3.0
# Name: Future, Length: 117, dtype: float64

# %%
df.groupby('ParentAirline')['Total'].sum()
# Out:
# ParentAirline
# Aegean Airlines          120.0
# Aeroflot                 448.0
# Aerolineas Argentinas    250.0
# Air Algerie              163.0
# Air Arabia                82.0
#                          ...
# Virgin Australia         208.0
# Volaris                   82.0
# WestJet                  193.0
# Wizz Air                  87.0
# easyJet                  452.0
# Name: Total, Length: 117, dtype: float64

# %%
df.groupby('AircraftType')['Current'].sum()
# Out:
# AircraftType
# ATR 42-300F/-320F                   26.0
# ATR 42-600                           0.0
# ATR 42/72                          439.0
# ATR 72-200F                         21.0
# ATR 72-600                           5.0
#                                    ...
# Tupolev Tu-154                       0.0
# Tupolev Tu-204                       0.0
# Tupolev Tu-214                       0.0
# Viking Air DHC 6-400 Twin Otter      2.0
# Yakovlev Yak-42                      0.0
# Name: Current, Length: 101, dtype: float64

# %%
df.groupby('AircraftType')['Future'].sum()
# Out:
# AircraftType
# ATR 42-300F/-320F                  0.0
# ATR 42-600                         0.0
# ATR 42/72                          5.0
# ATR 72-200F                        0.0
# ATR 72-600                         0.0
#                                   ...
# Tupolev Tu-154                     0.0
# Tupolev Tu-204                     0.0
# Tupolev Tu-214                     0.0
# Viking Air DHC 6-400 Twin Otter    0.0
# Yakovlev Yak-42                    0.0
# Name: Future, Length: 101, dtype: float64

# %%
df.groupby('AircraftType')['Total'].sum()
# Out:
# AircraftType
# ATR 42-300F/-320F                   26.0
# ATR 42-600                           2.0
# ATR 42/72                          869.0
# ATR 72-200F                         21.0
# ATR 72-600                          10.0
#                                    ...
# Tupolev Tu-154                       4.0
# Tupolev Tu-204                       8.0
# Tupolev Tu-214                       3.0
# Viking Air DHC 6-400 Twin Otter      2.0
# Yakovlev Yak-42                      1.0
# Name: Total, Length: 101, dtype: float64

# %%
df.describe(include='object')
# Out:
#        ParentAirline                Airline AircraftType UnitCost Totalcost
# count           1583                   1583         1583     1583      1583
# unique           117                    280          101       56       488
# top        Lufthansa  Scandinavian Airlines   Boeing 737       74         0
# freq             100                     22          147      145       716

# %% [markdown]
# ##### There are 117 different parent airlines, Lufthansa appears the most frequently.
#
# ##### Scandinavian Airlines appears the most – 22 times.
#
# ##### The Boeing 737 is the most popular aircraft, appearing 147 times in the data.
#
# ##### There are 56 unique values for how much each aircraft costs.

# %%
df.describe()
# Out:
#            Current       Future     Historic        Total       Orders  \
# count  1583.000000  1583.000000  1583.000000  1583.000000  1583.000000
# mean     13.041693     0.401769    10.204043    23.664561     5.807960
# std      32.545361     1.939423    20.998271    45.848572    22.930495
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     4.000000     0.000000
# 50%       2.000000     0.000000     3.000000    10.000000     0.000000
# 75%      14.000000     0.000000    11.000000    25.000000     0.000000
# max     718.000000    38.000000   325.000000   952.000000   400.000000
#
#         AverageAge
# count  1583.000000
# mean     10.115000
# std       4.935401
# min       0.100000
# 25%       8.600000
# 50%      10.115000
# 75%      10.115000
# max      39.000000

# %% [markdown]
# ##### The maximum values for some columns (like 718, 952, 400) are very high, while the average (mean) is quite low (around 10–23).
#
# ##### The 50th percentile (median) and 75th percentile for UnitCost are both 10.115, and the mean is 10.115 too.
#
# ##### The minimum and median total cost are 0, and even the 75th percentile is 0, despite the max being 400.

# %%
plt.figure(figsize=(20,9))
sb.set_theme(style="white")  
sb.countplot(x='AircraftType', data=df, palette="Set1")
plt.xticks(rotation=90)
plt.title("Aircraft type distributions across parent airlines", fontsize=16, fontweight="bold")
plt.xlabel("Aircraft type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### Boeing 737 and Airbus 320 has the most fleets, more than 100.
#
# ##### Most AircraftType having the fleets less than 100.

# %%
plt.figure(figsize=(15,6))

plt.subplot(1,3,1)
sb.histplot(df.Current, color='Brown')

plt.subplot(1,3,2)
sb.histplot(df.Future, color='Brown')

plt.subplot(1,3,3)
sb.histplot(df.Historic, color='Brown')

plt.suptitle("Fleet size variations (current, future, historic).", fontsize=12)

plt.show()

# %% [markdown]
# ##### The histogram is right-skewed, meaning most values are clustered on the lower end, and a few aircraft types have very high fleet counts.
#
# ##### Some aircraft types have more than 200, 300, or even 700 planes, but these are very rare.
#
# ##### Most Airlines Have No Future Or,Very Few Airlines Have Orders Between 1–5, Almost No Airlines Have Large Orders
#
# ##### The histogram is right-skewed, meaning most values are clustered on the lower end, and a few aircraft types have very high fleet counts.

# %%
sb.histplot(df.Totalcost,color='Brown')
plt.title("Cost trends across airlines and aircraft types.", fontsize=12)
plt.xlabel("Totalcost")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### The histogram is right-skewed, meaning most values are clustered on the lower end, between 0-10000.
#
# ##### Some aircraft types have 0 totalcost.

# %%
print(df.ParentAirline.unique())
a=input("Enter ParentAirline name:")
b=df[df.ParentAirline==a]
a
# Out:
# ['Aegean Airlines' 'Aeroflot' 'Aerolineas Argentinas' 'Air Algerie'
#  'Air Arabia' 'Air Astana' 'Air Berlin' 'Air Canada' 'Air China'
#  'Air Europa' 'Air France/KLM' 'Air India' 'Air Malta' 'Air Mauritius'
#  'Air Namibia' 'Air New Zealand' 'Air Transat'
#  'Air Transport International' 'Air Transport Services' 'Air Wisconsin'
#  'AirAsia' 'Alaska Airlines' 'Alitalia' 'All Nippon Airways'
#  'Allegiant Air' 'American Airlines' 'Asiana Airlines' 'Atlas Air'
#  'Avianca' 'Azul' 'Cathay Pacific' 'Cebu Pacific Air' 'China Airlines'
#  'China Eastern Airlines' 'China Southern Airlines' 'Copa Airlines'
#  'Delta Airlines' 'easyJet' 'EgyptAir' 'El Al' 'Emirates'
#  'Ethiopian Airlines' 'Etihad Airways' 'EVA Air' 'FedEx Express' 'Finnair'
#  'Flybe' 'FlyDubai' 'Frontier Airlines' 'Garuda Indonesia'
#  'Gol Linhas Aéreas' 'Grupo Aeromexico' 'Gulf Air' 'Hainan Airlines'
#  'Hawaiian Airlines' 'IAG' 'Iceland Air Group' 'IndiGo' 'Interjet'
# ...

# %%
sb.barplot(x=b.AircraftType, y=b.AverageAge, color='Brown')
plt.xticks(rotation=90)
plt.title("Age distribution for aircraft types and parent airlines.", fontsize=12)
plt.show()

# %% [markdown]
# ##### Only one aircrafttypes have more than 10 average age.
#
# ##### Almost aircrafttypes averageage is between 10.

# %%
sb.scatterplot(x='AverageAge', y='Totalcost', data=df)
plt.title("Relationships (average age vs. total cost).")
plt.show()

# %% [markdown]
# ##### Most airlinee have totalcost is between 0-10000.
#
# ##### only few airlines have more than 20000 totalcost.
#
# ##### An airlines which has lower totalcost have average age lower than 25.

# %%
df.groupby('Airline')['Totalcost'].sum().nlargest()
# Out:
# Airline
# American Airlines          103892
# United Airlines             90037
# Emirates                    85191
# Delta Airlines              79171
# China Southern Airlines     61370
# Name: Totalcost, dtype: int64

# %%
print(df.ParentAirline.unique())
a=input("Enter ParentAirline name:")
b=df[df.ParentAirline==a]
print(b.AircraftType.unique())
c=input("Enter AircraftType name:")
d=b[b.AircraftType==c]
d
# Out:
# ['Aegean Airlines' 'Aeroflot' 'Aerolineas Argentinas' 'Air Algerie'
#  'Air Arabia' 'Air Astana' 'Air Berlin' 'Air Canada' 'Air China'
#  'Air Europa' 'Air France/KLM' 'Air India' 'Air Malta' 'Air Mauritius'
#  'Air Namibia' 'Air New Zealand' 'Air Transat'
#  'Air Transport International' 'Air Transport Services' 'Air Wisconsin'
#  'AirAsia' 'Alaska Airlines' 'Alitalia' 'All Nippon Airways'
#  'Allegiant Air' 'American Airlines' 'Asiana Airlines' 'Atlas Air'
#  'Avianca' 'Azul' 'Cathay Pacific' 'Cebu Pacific Air' 'China Airlines'
#  'China Eastern Airlines' 'China Southern Airlines' 'Copa Airlines'
#  'Delta Airlines' 'easyJet' 'EgyptAir' 'El Al' 'Emirates'
#  'Ethiopian Airlines' 'Etihad Airways' 'EVA Air' 'FedEx Express' 'Finnair'
#  'Flybe' 'FlyDubai' 'Frontier Airlines' 'Garuda Indonesia'
#  'Gol Linhas Aéreas' 'Grupo Aeromexico' 'Gulf Air' 'Hainan Airlines'
#  'Hawaiian Airlines' 'IAG' 'Iceland Air Group' 'IndiGo' 'Interjet'
# ...

# %%
plt.boxplot(d.UnitCost)
plt.title("Compare unitcosts across different parent airlines and aircraft types")
plt.xlabel("AircraftType")
plt.ylabel("Unitcost")
plt.show()

# %% [markdown]
# ##### The Aegean Airlines have only two Airbus A319 aircrafttypes	having unitcost 90.

# %%
df.groupby('ParentAirline')[['Future','UnitCost']].mean()
# Out:
#                          Future    UnitCost
# ParentAirline
# Aegean Airlines        0.000000   65.400000
# Aeroflot               0.315789  103.631579
# Aerolineas Argentinas  0.250000  112.250000
# Air Algerie            0.076923  154.923077
# Air Arabia             0.000000   98.000000
# ...                         ...         ...
# Virgin Australia       0.076923   86.153846
# Volaris                1.333333  101.000000
# WestJet                0.250000   91.250000
# Wizz Air               2.000000  106.500000
# easyJet                0.375000   89.000000
#
# [117 rows x 2 columns]

# %%
df['Totalcost']=df['Totalcost'].astype('int64')

# %%
corr=df.corr(numeric_only=True)
corr
# Out:
#              Current    Future  Historic     Total    Orders  Totalcost  \
# Current     1.000000  0.487534  0.382510  0.906014  0.531695   0.795130
# Future      0.487534  1.000000  0.103641  0.436226  0.416421   0.483768
# Historic    0.382510  0.103641  1.000000  0.734535  0.154558   0.245929
# Total       0.906014  0.436226  0.734535  1.000000  0.465545   0.697621
# Orders      0.531695  0.416421  0.154558  0.465545  1.000000   0.479475
# Totalcost   0.795130  0.483768  0.245929  0.697621  0.479475   1.000000
# AverageAge -0.039665 -0.135222  0.128252  0.025812 -0.167138  -0.068898
#
#             AverageAge
# Current      -0.039665
# Future       -0.135222
# Historic      0.128252
# Total         0.025812
# Orders       -0.167138
# Totalcost    -0.068898
# AverageAge    1.000000

# %%
plt.figure(figsize=(10,5))
sb.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### Airlines with more current planes have higher total cost.
#
# ##### Total fleet is influenced by both current and historic numbers.
#
# ##### Aircraft age does not strongly affect other numbers like cost or orders.
#
# ##### American and United Airlines are spending the most on their fleets.

# %%
print(df.AircraftType.unique())
a=input("Enter ParentAirline name:")
b=df[df.AircraftType==a]
b=b.reset_index()
b
# Out:
# ['Airbus A319' 'Airbus A320' 'Airbus A321' 'ATR 42/72' 'Boeing 737'
#  'British Aerospace BAe 146/Avro RJ' 'De Havilland Canada DHC-8 Dash 8'
#  'Airbus A310' 'Airbus A330' 'Airbus A350' 'Antonov An-124'
#  'Antonov An-148/An-158' 'Boeing 747' 'Boeing 767' 'Boeing 777'
#  'Boeing 787' 'Ilyushin Il-62' 'Ilyushin Il-96' 'Irkut MC-21'
#  'McDonnell Douglas DC-10' 'McDonnell Douglas MD-11' 'Sukhoi Superjet 100'
#  'Tupolev Tu-134' 'Tupolev Tu-154' 'Tupolev Tu-204' 'Tupolev Tu-214'
#  'Viking Air DHC 6-400 Twin Otter' 'Yakovlev Yak-42' 'Airbus A340'
#  'Boeing 757' 'Embraer ERJ-190' 'McDonnell Douglas DC-9'
#  'McDonnell Douglas MD-80' 'Airbus A300' 'McDonnell Douglas DC-8'
#  'Fokker F50 / F60' 'Fokker F70 / F100' 'Boeing 727'
#  'Boeing 787 Dreamliner' 'Bombardier CS300' 'Canadair CRJ-100 Series'
#  'Embraer ERJ-170' 'Airbus A350 XWB' 'Canadair CRJ-700' 'Comac ARJ21'
#  'COMAC C919' 'Saab 340' 'Embraer ERJ-145' 'Aérospatiale/BAC Concorde'
# ...

# %%
plt.figure(figsize=(8,5))

plt.subplot(1,2,1)
sb.boxplot(b.UnitCost)
plt.xlabel("AircraftType")
plt.ylabel("UnitCost")

plt.subplot(1,2,2)
sb.boxplot(b.AverageAge)
plt.xlabel("AircraftType")
plt.ylabel("AverageAge")

plt.suptitle("Detect outliers in unit costs and average age", fontsize=12)
plt.show()

# %% [markdown]
# ##### The UnitCost boxplot shows the distribution of costs per unit for different airlines that use the Embraer ERJ-170 Aircrafttype.
#
# ##### All the airlines having Embraer ERJ-170 aircrafttpe has same unitcost.
#
# ##### The AverageAge boxplot shows the average age of the planes for each airline.
#
# ##### Almost aircrafttypes average age is between 5-10.

# %%
df['UnitCost']=df['UnitCost'].astype('float64')

# %%
plt.figure(figsize=(14,5))

plt.subplot(1,3,1)
sb.boxplot(df.Current)
plt.xlabel("AircraftType")
plt.ylabel("Current")

plt.subplot(1,3,2)
sb.boxplot(df.Future)
plt.xlabel("AircraftType")
plt.ylabel("Future")

plt.subplot(1,3,3)
sb.boxplot(df.Historic)
plt.xlabel("AircraftType")
plt.ylabel("Historic")

plt.suptitle("Evaluate discrepancies in fleet sizes (current, future, historic).", fontsize=12)

plt.show()

# %% [markdown]
# ##### Current, most values are in a similar range, but there are a few cases where things are much higher than usual.
#
# ##### The Future values are usually lower than Current values, There’s more difference in the data, and the values vary more than Current.
#
# ##### Historic values are also spread out, but not as much as Future.
#
# ##### There are some high values, but overall, the values are more consistent than Future.
